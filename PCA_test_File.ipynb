# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
import pandas as pd
df = pd.read_csv('upload_files/demo_metadata.tsv',sep='\t')

# %%
df = df.set_index('#SampleID')

# %%
df
# Out:
#           BarcodeSequence LinkerPrimerSequence     BodySite     Year    Month  \
# #SampleID
# #q2:types     categorical          categorical  categorical  numeric  numeric
# L1S8         AGCTGACTAGTC  GTGCCAGCMGCCGCGGTAA          gut     2008       10
# L1S57        ACACACTATGGC  GTGCCAGCMGCCGCGGTAA          gut     2009        1
# L1S76        ACTACGTGTGGT  GTGCCAGCMGCCGCGGTAA          gut     2009        2
# L1S105       AGTGCGATGCGT  GTGCCAGCMGCCGCGGTAA          gut     2009        3
# L2S155       ACGATGCGACCA  GTGCCAGCMGCCGCGGTAA    left palm     2009        1
# L2S175       AGCTATCCACGA  GTGCCAGCMGCCGCGGTAA    left palm     2009        2
# L2S204       ATGCAGCTCAGT  GTGCCAGCMGCCGCGGTAA    left palm     2009        3
# L2S222       CACGTGACATGT  GTGCCAGCMGCCGCGGTAA    left palm     2009        4
# L3S242       ACAGTTGCGCGA  GTGCCAGCMGCCGCGGTAA   right palm     2008       10
# L3S294       CACGACAGGCTA  GTGCCAGCMGCCGCGGTAA   right palm     2009        1
# ...

# %%
Sample_names = df['#SampleID'].drop(0)

# %%
Sample_names.values
# Out:
# array(['L1S8', 'L1S57', 'L1S76', 'L1S105', 'L2S155', 'L2S175', 'L2S204',
#        'L2S222', 'L3S242', 'L3S294', 'L3S313', 'L3S341', 'L3S360',
#        'L5S104', 'L5S155', 'L5S174', 'L5S203', 'L5S222', 'L1S140',
#        'L1S208', 'L1S257', 'L1S281', 'L2S240', 'L2S309', 'L2S357',
#        'L2S382', 'L3S378', 'L4S63', 'L4S112', 'L4S137', 'L5S240', 'L6S20',
#        'L6S68', 'L6S93'], dtype=object)

# %%
df.index.values
# Out:
# array(['#q2:types', 'L1S8', 'L1S57', 'L1S76', 'L1S105', 'L2S155', 'L2S175',
#        'L2S204', 'L2S222', 'L3S242', 'L3S294', 'L3S313', 'L3S341',
#        'L3S360', 'L5S104', 'L5S155', 'L5S174', 'L5S203', 'L5S222',
#        'L1S140', 'L1S208', 'L1S257', 'L1S281', 'L2S240', 'L2S309',
#        'L2S357', 'L2S382', 'L3S378', 'L4S63', 'L4S112', 'L4S137', 'L5S240',
#        'L6S20', 'L6S68', 'L6S93'], dtype=object)
