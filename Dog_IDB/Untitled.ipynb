# %%
import pandas as pd
import biom

# %%
df = pd.read_csv('833_prep_792_qiime_20180418-110622.txt',sep='\t')

# %%
table = biom.load_table('all.biom')
otu_df = table.to_dataframe()

# %%
df = df.set_index('#SampleID')

# %%
df.index
# Out:
# Index(['833.AHD.16', '833.AHD.17', '833.AHD.11', '833.AHD.12', '833.AHD.13',
#        '833.AHD.18', '833.AHD.19', '833.RVC08', '833.AHD.94', '833.RVC03',
#        ...
#        '833.Sweden.HC.2', '833.RVC12', '833.RVC15', '833.Mel.TX.HC13',
#        '833.California.HC28', '833.RVC16', '833.Leda.A73', '833.Mel.TX.HC14',
#        '833.Mel.TX.HC16', '833.Leda.C73'],
#       dtype='object', name='#SampleID', length=192)

# %%
otu_df = otu_df.T

# %%
df
# Out:
#                     BarcodeSequence LinkerPrimerSequence center_name  \
# #SampleID
# 833.AHD.16             CAGCTCATCAGC  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.17             CAAACAACAGCT  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.11             GTAGATCGTGTA  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.12             TAACGTGTGTGC  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.13             CATTATGGCGTG  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.18             GCAACACCATCC  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.19             GCGATATATCGC  GTGCCAGCMGCCGCGGTAA        CCME
# 833.RVC08              CGCTGTGGATTA  GTGCCAGCMGCCGCGGTAA        CCME
# 833.AHD.94             GAATACCAAGTC  GTGCCAGCMGCCGCGGTAA        CCME
# 833.RVC03              CGGGTGTTTGCT  GTGCCAGCMGCCGCGGTAA        CCME
# 833.RVC01              TTGATCCGGTAG  GTGCCAGCMGCCGCGGTAA        CCME
# 833.Leda.A61           ACAATAGACACC  GTGCCAGCMGCCGCGGTAA        CCME
# ...

# %%
sample_info = pd.read_csv('833_20180418-110621.txt',sep='\t')

# %%
sample_info
# Out:
#              sample_name   age  age_group age_unit  altitude  anonymized_name  \
# 0             833.AHD.11   2.0        1.0    years         0           AHD.11
# 1             833.AHD.12   4.0        2.0    years         0           AHD.12
# 2             833.AHD.13   8.0        3.0    years         0           AHD.13
# 3             833.AHD.14   4.0        2.0    years         0           AHD.14
# 4             833.AHD.15   1.0        1.0    years         0           AHD.15
# 5             833.AHD.16   2.0        1.0    years         0           AHD.16
# 6             833.AHD.17   5.0        2.0    years         0           AHD.17
# 7             833.AHD.18   6.0        3.0    years         0           AHD.18
# 8             833.AHD.19   3.0        2.0    years         0           AHD.19
# 9             833.AHD.21   7.0        3.0    years         0           AHD.21
# 10            833.AHD.22  12.0        4.0    years         0           AHD.22
# ...

# %%
sample_info.columns
# Out:
# Index(['sample_name', 'age', 'age_group', 'age_unit', 'altitude',
#        'anonymized_name', 'antibiotics', 'bcs', 'bcs_grouping', 'body_habitat',
#        'body_product', 'body_site', 'breed', 'breed_grouping',
#        'collection_date', 'collection_timestamp', 'country',
#        'crude_fiber_1000kcalg_me_group', 'depth', 'description', 'dewormed',
#        'disease_stat', 'dna_extracted', 'elevation', 'emp_status', 'env_biome',
#        'env_feature', 'g_fat_1000kcal_me_group', 'g_protein_1000kcal_me_group',
#        'gender_specific', 'has_extracted_data', 'has_physical_specimen',
#        'histo', 'host_common_name', 'host_scientific_name', 'host_subject_id',
#        'host_taxid', 'indiv_g_fat_1000kcal_me_group',
#        'indiv_g_protein_1000kcal_me_group', 'indoor_outdoor', 'latitude',
#        'longitude', 'perc_crude_protein_min_group',
#        'percent_crude_fat_min_group', 'percent_crude_fiber_max_group',
# ...

# %%
sample_info['disease_stat']
# Out:
# 0      acute hem. diarrhea
# 1      acute hem. diarrhea
# 2      acute hem. diarrhea
# 3      acute hem. diarrhea
# 4      acute hem. diarrhea
# 5      acute hem. diarrhea
# 6      acute hem. diarrhea
# 7      acute hem. diarrhea
# 8      acute hem. diarrhea
# 9      acute hem. diarrhea
# 10     acute hem. diarrhea
# 11     acute hem. diarrhea
# 12     acute hem. diarrhea
# 13     acute hem. diarrhea
# 14     acute hem. diarrhea
# 15                 healthy
# 16                 healthy
# 17                 healthy
# 18                 healthy
# 19                 healthy
# 20                 healthy
# 21                 healthy
# 22                 healthy
# 23                 healthy
# 24                 healthy
# 25                 healthy
# 26                 healthy
# 27                 healthy
# 28                 healthy
# 29                 healthy
#               ...
# 162                healthy
# 163                healthy
# 164                healthy
# ...

# %%
# Out:
# Index(['BarcodeSequence', 'LinkerPrimerSequence', 'center_name',
#        'experiment_center', 'experiment_design_description',
#        'experiment_title', 'instrument_model', 'library_construction_protocol',
#        'linker', 'pcr_primers', 'platform', 'platformchemistry', 'pool_name',
#        'primer_plate', 'run_center', 'run_date', 'run_prefix', 'samp_size',
#        'sample_center', 'sample_plate', 'sequencing_meth', 'target_gene',
#        'target_subfragment', 'well_id', 'qiita_prep_id', 'age', 'age_group',
#        'age_unit', 'altitude', 'anonymized_name', 'antibiotics', 'bcs',
#        'bcs_grouping', 'body_habitat', 'body_product', 'body_site', 'breed',
#        'breed_grouping', 'collection_date', 'collection_timestamp', 'country',
#        'crude_fiber_1000kcalg_me_group', 'depth', 'dewormed', 'disease_stat',
#        'dna_extracted', 'elevation', 'emp_status', 'env_biome', 'env_feature',
#        'g_fat_1000kcal_me_group', 'g_protein_1000kcal_me_group',
# ...
